# %%
import numpy as np
import pandas as pd

# %%
frame = pd.DataFrame(np.random.randn(4,3),columns=list('bde'),index = ['Utah','Ohio','Texas','Oregon'])

# %%
frame
# Out:
#                b         d         e
# Utah    1.679737 -2.421196 -0.636279
# Ohio    0.729598 -1.078160 -0.904446
# Texas   0.995295  1.027000  0.303009
# Oregon -0.953427  0.711638  0.653310

# %%
np.abs(frame)
# Out:
#                b         d         e
# Utah    1.679737  2.421196  0.636279
# Ohio    0.729598  1.078160  0.904446
# Texas   0.995295  1.027000  0.303009
# Oregon  0.953427  0.711638  0.653310

# %%
f = lambda x:x.max()-x.min()
frame.apply(f)
# Out:
# b    2.633163
# d    3.448197
# e    1.557756
# dtype: float64

# %%
frame.apply(f,axis=1)
# Out:
# Utah      4.100933
# Ohio      1.807758
# Texas     0.723992
# Oregon    1.665065
# dtype: float64

# %%
frame.apply(f,axis='columns')
# Out:
# Utah      4.100933
# Ohio      1.807758
# Texas     0.723992
# Oregon    1.665065
# dtype: float64

# %%
frame.apply(f,axis='rows')
# Out:
# b    2.633163
# d    3.448197
# e    1.557756
# dtype: float64

# %%
frame[frame<0.5]
# Out:
#                b         d         e
# Utah         NaN -2.421196 -0.636279
# Ohio         NaN -1.078160 -0.904446
# Texas        NaN       NaN  0.303009
# Oregon -0.953427       NaN       NaN

# %%
data = {'Col_1':[23,43,12],
        'Col_2':[52,89,86]}

# %%
frame2 = pd.DataFrame(data,columns=['Col_1','Col_2'],index=['B','A','C'])

# %%
frame2.index.name='ID'

# %%
frame2
# Out:
#     Col_1  Col_2
# ID
# B      23     52
# A      43     89
# C      12     86

# %%
val = pd.Series([23,12,10],index=['B','A','C'])

# %%
frame2['Col_3']=val

# %%
frame2
# Out:
#     Col_1  Col_2  Col_3
# ID
# B      23     52     23
# A      43     89     12
# C      12     86     10

# %%
frame3 = frame2.reindex(['A','B','C'])

# %%
frame3
# Out:
#     Col_1  Col_2  Col_3
# ID
# A      43     89     12
# B      23     52     23
# C      12     86     10

# %%
frame4 = frame3.drop('C')

# %%
frame4
# Out:
#     Col_1  Col_2  Col_3
# ID
# A      43     89     12
# B      23     52     23

# %% [markdown]
# **Sort the data with the values as per the column in the decreasing order**

# %%
frame2.sort_values(by='Col_1',ascending=False)
# Out:
#     Col_1  Col_2  Col_3
# ID
# A      43     89     12
# B      23     52     23
# C      12     86     10
