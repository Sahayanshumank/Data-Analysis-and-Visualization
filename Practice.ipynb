# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({A:10,np.nan,6},{B:10,11,np.nan})
# Out:
#   Cell In[4], line 1
#     df = pd.DataFrame({A:10,np.nan,6}:{B:10,11,np.nan})
#                                  ^
# SyntaxError: ':' expected after dictionary key
