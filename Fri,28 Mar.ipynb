# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'staff':['A','B','C','D','E','F'],
                    'issues':[18,22,29,25,14,11],
                    'assists':[4,5,5,4,8,12],
                    'rebounds':[10,6,4,6,3,5]})

# %%
print(df1)
# Out:
#   staff  issues  assists  rebounds
# 0     A      18        4        10
# 1     B      22        5         6
# 2     C      29        5         4
# 3     D      25        4         6
# 4     E      14        8         3
# 5     F      11       12         5

# %%
df2 = pd.DataFrame({'staff':['A','B','C','D','E','F'],
                    'issues':[22,25,27,35,25,20],
                    'assists':[15,13,8,8,5,8],
                    'rebs':[4,11,12,8,7,10]})

# %%
print(df2)
# Out:
#   staff  issues  assists  rebs
# 0     A      22       15     4
# 1     B      25       13    11
# 2     C      27        8    12
# 3     D      35        8     8
# 4     E      25        5     7
# 5     F      20        8    10

# %%
df1.corrwith(df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df1.corrwith(df2)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11311, in DataFrame.corrwith(self, other, axis, drop, method, numeric_only)
#   11308 right = right + left * 0
#   11310 # demeaned data
# > 11311 ldem = left - left.mean(numeric_only=numeric_only)
#   11312 rdem = right - right.mean(numeric_only=numeric_only)
#   11314 num = (ldem * rdem).sum()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
# ...

# %%
df = {
    "Array_":[30,70,100],
    "Array_2":[65.1,49.50,30.7]
}

# %%
data = pd.DataFrame(df)

# %%
print(data.corr())
# Out:
#            Array_   Array_2
# Array_   1.000000 -0.990773
# Array_2 -0.990773  1.000000
